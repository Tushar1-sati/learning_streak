# %%
import pandas as pd
df=pd.read_csv(r'D:\github page\1_numpy&pandas\unicorn.csv')
df
# Out:
#           Company  Valuation Date Joined                         Industry  \
# 0       Bytedance        180  07-04-2017          Artificial intelligence
# 1          SpaceX        100  01-12-2012                            Other
# 2           SHEIN        100  03-07-2018  E-commerce & direct-to-consumer
# 3          Stripe         95  23-01-2014                          Fintech
# 4          Klarna         46  12-12-2011                          Fintech
# ...           ...        ...         ...                              ...
# 1069     Zhaogang          1  29-06-2017  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# 1071     Zihaiguo          1  06-05-2021                Consumer & retail
# 1072         Zopa          1  19-10-2021                          Fintech
# 1073        Zwift          1  16-09-2020  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  Funding
# ...

# %%
df=df.set_index('Company')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27560\2644771528.py in ?()
# ----> 1 df=df.set_index('Company')
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6140                     if not found:
#    6141                         missing.append(col)
#    6142
#    6143         if missing:
# -> 6144             raise KeyError(f"None of {missing} are in the columns")
#    6145
#    6146         if inplace:
#    6147             frame = self
#
# KeyError: "None of ['Company'] are in the columns"

# %% [markdown]
# df.reset_index to get original data back after set index

# %%
df[df['Country']=='United Kingdom']
# Out:
#                           Valuation Date Joined  \
# Company
# Checkout.com                     40  02-05-2019
# Revolut                          33  26-04-2018
# Rapyd                            15  03-12-2019
# Blockchain.com                   14  17-02-2021
# Global Switch                    11  22-12-2016
# Hopin                             8  10-11-2020
# Howden Group Holdings             5  29-09-2020
# Monzo                             5  31-10-2018
# Lendable                          5  31-03-2021
# ZEPZ                              5  23-08-2021
# Greensill                         4  16-07-2018
# OakNorth Bank                     3  12-10-2017
# Graphcore                         3  18-12-2018
# CMR Surgical                      3  17-09-2019
# Bought By Many                    2  01-06-2021
# BGL Group                         2  24-11-2017
# Improbable                        2  11-05-2017
# BrewDog                           2  10-04-2017
# ...

# %%
df[(df['Country']=='United Kingdom') & (df['Funding']>500)]
# Out:
#                Valuation Date Joined                 Industry          City  \
# Company
# Rapyd                 15  03-12-2019                  Fintech        London
# ZEPZ                   5  23-08-2021                  Fintech        London
# Graphcore              3  18-12-2018  Artificial intelligence       Bristol
# CMR Surgical           3  17-09-2019                   Health     Cambridge
# BGL Group              2  24-11-2017                  Fintech  Peterborough
# Improbable             2  11-05-2017                    Other        London
# Gett                   2  24-05-2016    Auto & transportation        London
# GoCardless             2  08-02-2022                  Fintech        London
# Starling Bank          2  08-03-2021                  Fintech        London
# Zopa                   1  19-10-2021                  Fintech        London
#
#                       Country Continent  Year Founded  Funding
# Company
# ...

# %% [markdown]
# loc and .iloc

# %%
df.loc['SpaceX','City']
# Out:
# 'Hawthorne'

# %%
df.loc['Zopa':'Zwift','Industry':'City']
# Out:
#                                 Industry        City
# Company
# Zopa                             Fintech      London
# Zwift    E-commerce & direct-to-consumer  Long Beach

# %%
df.iloc[3,4]
# Out:
# 'United States'

# %%
df
# Out:
#              Valuation Date Joined                         Industry  \
# Company
# Bytedance          180  07-04-2017          Artificial intelligence
# SpaceX             100  01-12-2012                            Other
# SHEIN              100  03-07-2018  E-commerce & direct-to-consumer
# Stripe              95  23-01-2014                          Fintech
# Klarna              46  12-12-2011                          Fintech
# ...                ...         ...                              ...
# Zhaogang             1  29-06-2017  E-commerce & direct-to-consumer
# Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# Zihaiguo             1  06-05-2021                Consumer & retail
# Zopa                 1  19-10-2021                          Fintech
# Zwift                1  16-09-2020  E-commerce & direct-to-consumer
#
#                       City         Country      Continent  Year Founded  \
# Company
# ...

# %%
df.iloc[1,-2]
# Out:
# np.int64(2002)

# %%
import pandas as pd
import requests

url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies" 
""

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

print(response.status_code)

tables = pd.read_html(response.text)
data=tables[0]
data
# Out:
# 200
# C:\Users\tusha\AppData\Local\Temp\ipykernel_10320\2235869911.py:15: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
# ...

# %%
data1=data[data['GICS Sub-Industry']=='Biotechnology']

# %%
data1.iloc[-3:,1]
# Out:
# 318                      Moderna
# 391    Regeneron Pharmaceuticals
# 471       Vertex Pharmaceuticals
# Name: Security, dtype: object

# %% [markdown]
# add two row column horizontaly, vertically

# %%
data1
# Out:
#     Symbol                   Security  GICS Sector GICS Sub-Industry  \
# 3     ABBV                     AbbVie  Health Care     Biotechnology
# 32    AMGN                      Amgen  Health Care     Biotechnology
# 64    BIIB                     Biogen  Health Care     Biotechnology
# 220   GILD            Gilead Sciences  Health Care     Biotechnology
# 249   INCY                     Incyte  Health Care     Biotechnology
# 318   MRNA                    Moderna  Health Care     Biotechnology
# 391   REGN  Regeneron Pharmaceuticals  Health Care     Biotechnology
# 471   VRTX     Vertex Pharmaceuticals  Health Care     Biotechnology
#
#          Headquarters Location  Date added      CIK      Founded
# 3      North Chicago, Illinois  2012-12-31  1551152  2013 (1888)
# 32   Thousand Oaks, California  1992-01-02   318154         1980
# 64    Cambridge, Massachusetts  2003-11-13   875045         1978
# 220    Foster City, California  2004-07-01   882095         1987
# ...

# %%
data1.reset_index()
# Out:
#   Symbol                   Security  GICS Sector GICS Sub-Industry  \
# 0   ABBV                     AbbVie  Health Care     Biotechnology
# 1   AMGN                      Amgen  Health Care     Biotechnology
# 2   BIIB                     Biogen  Health Care     Biotechnology
# 3   GILD            Gilead Sciences  Health Care     Biotechnology
# 4   INCY                     Incyte  Health Care     Biotechnology
# 5   MRNA                    Moderna  Health Care     Biotechnology
# 6   REGN  Regeneron Pharmaceuticals  Health Care     Biotechnology
# 7   VRTX     Vertex Pharmaceuticals  Health Care     Biotechnology
#
#        Headquarters Location  Date added      CIK      Founded
# 0    North Chicago, Illinois  2012-12-31  1551152  2013 (1888)
# 1  Thousand Oaks, California  1992-01-02   318154         1980
# 2   Cambridge, Massachusetts  2003-11-13   875045         1978
# 3    Foster City, California  2004-07-01   882095         1987
# ...

# %%
data1=data[['Security','GICS Sector','GICS Sub-Industry','Symbol']]
data1.set_index('Symbol')
# Out:
#                    Security             GICS Sector  \
# Symbol
# MMM                      3M             Industrials
# AOS             A. O. Smith             Industrials
# ABT     Abbott Laboratories             Health Care
# ABBV                 AbbVie             Health Care
# ACN               Accenture  Information Technology
# ...                     ...                     ...
# XYL              Xylem Inc.             Industrials
# YUM             Yum! Brands  Consumer Discretionary
# ZBRA     Zebra Technologies  Information Technology
# ZBH           Zimmer Biomet             Health Care
# ZTS                  Zoetis             Health Care
#
#                                    GICS Sub-Industry
# Symbol
# MMM                         Industrial Conglomerates
# AOS                                Building Products
# ABT                            Health Care Equipment
# ABBV                                   Biotechnology
# ...
