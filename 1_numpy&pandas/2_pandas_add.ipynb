# %%
import pandas as pd
import requests

url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies" 
""

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

print(response.status_code)

tables = pd.read_html(response.text)
data=tables[0]
data
# Out:
# 200
# C:\Users\tusha\AppData\Local\Temp\ipykernel_26324\838413954.py:15: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
# ...

# %%
data=data.set_index('Symbol')

# %%
data1=data[['Security','GICS Sector','GICS Sub-Industry']]
data1
# Out:
#                    Security             GICS Sector  \
# Symbol
# MMM                      3M             Industrials
# AOS             A. O. Smith             Industrials
# ABT     Abbott Laboratories             Health Care
# ABBV                 AbbVie             Health Care
# ACN               Accenture  Information Technology
# ...                     ...                     ...
# XYL              Xylem Inc.             Industrials
# YUM             Yum! Brands  Consumer Discretionary
# ZBRA     Zebra Technologies  Information Technology
# ZBH           Zimmer Biomet             Health Care
# ZTS                  Zoetis             Health Care
#
#                                    GICS Sub-Industry
# Symbol
# MMM                         Industrial Conglomerates
# AOS                                Building Products
# ABT                            Health Care Equipment
# ABBV                                   Biotechnology
# ...

# %%
data2=data.iloc[:,-3:]
data2
# Out:
#         Date added      CIK      Founded
# Symbol
# MMM     1957-03-04    66740         1902
# AOS     2017-07-26    91142         1916
# ABT     1957-03-04     1800         1888
# ABBV    2012-12-31  1551152  2013 (1888)
# ACN     2011-07-06  1467373         1989
# ...            ...      ...          ...
# XYL     2011-11-01  1524472         2011
# YUM     1997-10-06  1041061         1997
# ZBRA    2019-12-23   877212         1969
# ZBH     2001-08-07  1136869         1927
# ZTS     2013-06-21  1555280         1952
#
# [503 rows x 3 columns]

# %%
pd.merge(data1,data2,on='Symbol')
# Out:
#                    Security             GICS Sector  \
# Symbol
# MMM                      3M             Industrials
# AOS             A. O. Smith             Industrials
# ABT     Abbott Laboratories             Health Care
# ABBV                 AbbVie             Health Care
# ACN               Accenture  Information Technology
# ...                     ...                     ...
# XYL              Xylem Inc.             Industrials
# YUM             Yum! Brands  Consumer Discretionary
# ZBRA     Zebra Technologies  Information Technology
# ZBH           Zimmer Biomet             Health Care
# ZTS                  Zoetis             Health Care
#
#                                    GICS Sub-Industry  Date added      CIK  \
# Symbol
# MMM                         Industrial Conglomerates  1957-03-04    66740
# AOS                                Building Products  2017-07-26    91142
# ABT                            Health Care Equipment  1957-03-04     1800
# ...

# %%
import numpy as np
np1=np.random.randint(100,200,25).reshape(5,5)
df1=pd.DataFrame(np1,index=['r1','r2','r3','r4','r5'],columns=['cr1','cr2','cr3','cr4','cr5'])
df1
# Out:
#     cr1  cr2  cr3  cr4  cr5
# r1  158  158  119  131  107
# r2  141  120  169  152  120
# r3  149  152  182  155  131
# r4  163  165  181  162  112
# r5  131  195  129  128  188

# %%
np1=np.random.randint(100,200,25).reshape(5,5)
df2=pd.DataFrame(np1,index=['r1','r2','r3','r4','r5'],columns=['c1','c2','c3','c4','c5'])
df2
# Out:
#      c1   c2   c3   c4   c5
# r1  129  142  102  187  108
# r2  162  162  161  134  151
# r3  121  133  126  110  135
# r4  130  155  164  141  118
# r5  169  100  153  158  151

# %%
df1.index.name='i1'
df2.index.name='i1'
pd.merge(df1,df2,on='i1')
# Out:
#     cr1  cr2  cr3  cr4  cr5   c1   c2   c3   c4   c5
# i1
# r1  158  158  119  131  107  129  142  102  187  108
# r2  141  120  169  152  120  162  162  161  134  151
# r3  149  152  182  155  131  121  133  126  110  135
# r4  163  165  181  162  112  130  155  164  141  118
# r5  131  195  129  128  188  169  100  153  158  151

# %% [markdown]
# ##DELETe row and column use drop ,axis function

# %%
data.drop('AOS',axis=0)
# Out:
#                    Security             GICS Sector  \
# Symbol
# MMM                      3M             Industrials
# ABT     Abbott Laboratories             Health Care
# ABBV                 AbbVie             Health Care
# ACN               Accenture  Information Technology
# ADBE             Adobe Inc.  Information Technology
# ...                     ...                     ...
# XYL              Xylem Inc.             Industrials
# YUM             Yum! Brands  Consumer Discretionary
# ZBRA     Zebra Technologies  Information Technology
# ZBH           Zimmer Biomet             Health Care
# ZTS                  Zoetis             Health Care
#
#                                    GICS Sub-Industry    Headquarters Location  \
# Symbol
# MMM                         Industrial Conglomerates    Saint Paul, Minnesota
# ABT                            Health Care Equipment  North Chicago, Illinois
# ABBV                                   Biotechnology  North Chicago, Illinois
# ...

# %%
data.drop(['ZBRA','ZBH','ZTS'],axis=0)
# Out:
#                    Security             GICS Sector  \
# Symbol
# MMM                      3M             Industrials
# AOS             A. O. Smith             Industrials
# ABT     Abbott Laboratories             Health Care
# ABBV                 AbbVie             Health Care
# ACN               Accenture  Information Technology
# ...                     ...                     ...
# WDAY          Workday, Inc.  Information Technology
# WYNN           Wynn Resorts  Consumer Discretionary
# XEL             Xcel Energy               Utilities
# XYL              Xylem Inc.             Industrials
# YUM             Yum! Brands  Consumer Discretionary
#
#                                    GICS Sub-Industry    Headquarters Location  \
# Symbol
# MMM                         Industrial Conglomerates    Saint Paul, Minnesota
# AOS                                Building Products     Milwaukee, Wisconsin
# ABT                            Health Care Equipment  North Chicago, Illinois
# ...
