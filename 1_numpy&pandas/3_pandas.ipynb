# %% [markdown]
# Readcsv function

# %%
import pandas as pd
df1=pd.read_csv(r'D:\github page\1_numpy&pandas\data.csv')
df1
# Out:
#             Date    SP500  Dividend  Earnings  Consumer Price Index  \
# 0     1871-01-01     4.44      0.26       0.4                 12.46
# 1     1871-02-01     4.50      0.26       0.4                 12.84
# 2     1871-03-01     4.61      0.26       0.4                 13.03
# 3     1871-04-01     4.74      0.26       0.4                 12.56
# 4     1871-05-01     4.86      0.26       0.4                 12.27
# ...          ...      ...       ...       ...                   ...
# 1861  2026-02-01  6893.81      0.00       0.0                  0.00
# 1862  2026-03-01  6654.42      0.00       0.0                  0.00
# 1863  2026-04-01  6957.01      0.00       0.0                  0.00
# 1864  2026-05-01  7412.55      0.00       0.0                  0.00
# 1865  2026-06-01  7450.03      0.00       0.0                  0.00
#
#       Long Interest Rate  Real Price  Real Dividend  Real Earnings  PE10
# 0                   5.32      109.05           6.39           9.82   0.0
# ...

# %%
df2=pd.read_csv(r'D:\github page\1_numpy&pandas\constituents.csv')
df2
# Out:
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
dff1=pd.read_excel(r'D:\github page\1_numpy&pandas\Complete-List-of-SP-500-Index-Companies-July-4-2026.xlsx')
dff1
# Out:
#      S.No.          Company Name Ticker                  Sector
# 0        1             Apple Inc   AAPL  Information Technology
# 1        2        Microsoft Corp   MSFT  Information Technology
# 2        3        Amazon Com Inc   AMZN  Consumer Discretionary
# 3        4           Nvidia Corp   NVDA  Information Technology
# 4        5  Alphabet Inc Class A  GOOGL           Communication
# ..     ...                   ...    ...                     ...
# 499    500      Fox Corp Class B    FOX           Communication
# 500    501        Blackstone Inc     BX              Financials
# 501    502            Airbnb Inc   ABNB  Consumer Discretionary
# 502    503     News Corp Class B    NWS           Communication
# 503    504    Expand Energy Corp    EXE                  Energy
#
# [504 rows x 4 columns]

# %% [markdown]
# Read html use data from other sites

# %%
import pandas as pd
import requests

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
                  "(KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
}

session = requests.Session()
session.headers.update(headers)

# NSE requires you to visit the homepage first to get valid cookies
session.get("https://www.nseindia.com", timeout=5)

url = "https://archives.nseindia.com/content/indices/ind_nifty50list.csv"
response = session.get(url, timeout=5)
response.raise_for_status()

with open("nifty50list.csv", "wb") as f:
    f.write(response.content)

df3 = pd.read_csv("nifty50list.csv")
df3
# Out:
#                                   Company Name  \
# 0                       Adani Enterprises Ltd.
# 1   Adani Ports and Special Economic Zone Ltd.
# 2             Apollo Hospitals Enterprise Ltd.
# 3                            Asian Paints Ltd.
# 4                               Axis Bank Ltd.
# 5                              Bajaj Auto Ltd.
# 6                           Bajaj Finance Ltd.
# 7                           Bajaj Finserv Ltd.
# 8                      Bharat Electronics Ltd.
# 9                           Bharti Airtel Ltd.
# 10                                  Cipla Ltd.
# 11                             Coal India Ltd.
# 12               Dr. Reddy's Laboratories Ltd.
# 13                          Eicher Motors Ltd.
# 14                                Eternal Ltd.
# 15                      Grasim Industries Ltd.
# 16                       HCL Technologies Ltd.
# 17                              HDFC Bank Ltd.
# 18            HDFC Life Insurance Company Ltd.
# ...

# %%
df3.head(10)
df3.info()
df3.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company Name  50 non-null     object
#  1   Industry      50 non-null     object
#  2   Symbol        50 non-null     object
#  3   Series        50 non-null     object
#  4   ISIN Code     50 non-null     object
# dtypes: object(5)
# memory usage: 2.1+ KB
#                   Company Name            Industry    Symbol Series  \
# count                       50                  50        50     50
# unique                      50                  15        50      1
# top     Adani Enterprises Ltd.  Financial Services  ADANIENT     EQ
# freq                         1                  11         1     50
#
#            ISIN Code
# count             50
# unique            50
# top     INE423A01024
# freq               1

# %%
df3.index
df3.columns
# Out:
# Index(['Company Name', 'Industry', 'Symbol', 'Series', 'ISIN Code'], dtype='object')

# %% [markdown]
# Subseting-where i need only one and two column ,here we use square bracket and list for using more than one column

# %%
df3[['Symbol','Industry']]
# Out:
#         Symbol                        Industry
# 0     ADANIENT                 Metals & Mining
# 1   ADANIPORTS                        Services
# 2   APOLLOHOSP                      Healthcare
# 3   ASIANPAINT               Consumer Durables
# 4     AXISBANK              Financial Services
# 5   BAJAJ-AUTO  Automobile and Auto Components
# 6   BAJFINANCE              Financial Services
# 7   BAJAJFINSV              Financial Services
# 8          BEL                   Capital Goods
# 9   BHARTIARTL               Telecommunication
# 10       CIPLA                      Healthcare
# 11   COALINDIA      Oil Gas & Consumable Fuels
# 12     DRREDDY                      Healthcare
# 13   EICHERMOT  Automobile and Auto Components
# 14     ETERNAL               Consumer Services
# 15      GRASIM          Construction Materials
# 16     HCLTECH          Information Technology
# 17    HDFCBANK              Financial Services
# 18    HDFCLIFE              Financial Services
# ...

# %% [markdown]
# how to filter a data in data frame

# %%
import pandas as pd
import requests

url = "https://stockanalysis.com/list/dow-jones-stocks/" 
""

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

print(response.status_code)

tables = pd.read_html(response.text)
data=tables[0]
data
# Out:
# 200
# C:\Users\tusha\AppData\Local\Temp\ipykernel_28960\56720991.py:15: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)
#     No. Symbol                                 Company Name Market Cap  \
# 0     1   NVDA                           NVIDIA Corporation      4.98T
# 1     2   AAPL                                   Apple Inc.      4.82T
# 2     3  GOOGL                                Alphabet Inc.      4.26T
# 3     4   MSFT                        Microsoft Corporation      2.96T
# 4     5   AMZN                             Amazon.com, Inc.      2.67T
# 5     6    JPM                         JPMorgan Chase & Co.    917.61B
# 6     7    WMT                                 Walmart Inc.    874.83B
# 7     8      V                                    Visa Inc.    675.23B
# ...

# %% [markdown]
# adding a new column

# %%
data['new']=data['Stock Price']+10
data
# Out:
#     No. Symbol                                 Company Name Market Cap  \
# 0     1   NVDA                           NVIDIA Corporation      4.98T
# 1     2   AAPL                                   Apple Inc.      4.82T
# 2     3  GOOGL                                Alphabet Inc.      4.26T
# 3     4   MSFT                        Microsoft Corporation      2.96T
# 4     5   AMZN                             Amazon.com, Inc.      2.67T
# 5     6    JPM                         JPMorgan Chase & Co.    917.61B
# 6     7    WMT                                 Walmart Inc.    874.83B
# 7     8      V                                    Visa Inc.    675.23B
# 8     9    JNJ                            Johnson & Johnson    599.76B
# 9    10   CSCO                          Cisco Systems, Inc.    438.09B
# 10   11    CAT                             Caterpillar Inc.    412.19B
# 11   12    UNH              UnitedHealth Group Incorporated    395.04B
# ...

# %% [markdown]
# changing index
# set_index

# %%
data.set_index('Symbol')
# Out:
#         No.                                 Company Name Market Cap  \
# Symbol
# NVDA      1                           NVIDIA Corporation      4.98T
# AAPL      2                                   Apple Inc.      4.82T
# GOOGL     3                                Alphabet Inc.      4.26T
# MSFT      4                        Microsoft Corporation      2.96T
# AMZN      5                             Amazon.com, Inc.      2.67T
# JPM       6                         JPMorgan Chase & Co.    917.61B
# WMT       7                                 Walmart Inc.    874.83B
# V         8                                    Visa Inc.    675.23B
# JNJ       9                            Johnson & Johnson    599.76B
# CSCO     10                          Cisco Systems, Inc.    438.09B
# CAT      11                             Caterpillar Inc.    412.19B
# UNH      12              UnitedHealth Group Incorporated    395.04B
# CVX      13                          Chevron Corporation    375.47B
# ...
